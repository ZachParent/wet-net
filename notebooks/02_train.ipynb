# %% [markdown]
# # Train the model

# %%
import pandas as pd

from wet_net.paths import RESULTS_DIR

df = pd.read_csv(RESULTS_DIR / "dummy_results.csv")

df.head()
# Out:
#    success            timestamp
# 0     True  2025-01-01 12:00:00
